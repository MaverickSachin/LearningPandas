# %%
import pandas as pd

# %%
df = pd.read_csv("Data/survey_results_public.csv")
schema_df = pd.read_csv("Data/survey_results_schema.csv")

# %%
pd.set_option("display.max_columns", 85)
pd.set_option("display.max_rows", 85)
pd.set_option("display.max_colwidth", None)

# %%
schema_df.set_index("Column", inplace=True)

# %%
schema_df.sort_index()
# Out:
#                                                                                                                                                                                                                                                                                                                                                             QuestionText
# Column
# Age                                                                                                                                                                                                                                                                         What is your age (in years)? If you prefer not to answer, you may leave this question blank.
# ...

# %%
high_salary_filter = (df["ConvertedComp"] > 70000)

# %%
df.loc[high_salary_filter, ["Country", "LanguageWorkedWith", "ConvertedComp"]]
# Out:
#               Country  \
# 5              Canada
# 8         New Zealand
# 12      United States
# 15     United Kingdom
# 21      United States
# ...               ...
# 88323   United States
# 88324   United States
# 88325   United States
# 88326         Finland
# 88329     Netherlands
#
#                                                                                        LanguageWorkedWith  \
# 5                                                                                              Java;R;SQL
# 8      Bash/Shell/PowerShell;C#;HTML/CSS;JavaScript;Python;Ruby;Rust;SQL;TypeScript;WebAssembly;Other(s):
# 12                                           Bash/Shell/PowerShell;HTML/CSS;JavaScript;PHP;SQL;TypeScript
# 15                                            Bash/Shell/PowerShell;C#;HTML/CSS;JavaScript;TypeScript;VBA
# 21                               Bash/Shell/PowerShell;C++;HTML/CSS;JavaScript;Python;Ruby;SQL;TypeScript
# ...

# %%
countries = ["United States", "India", "Canada", "United Kingdom", "Germany"]
country_filter = (df["Country"].isin(countries))

# %%
df.loc[country_filter, "Country"]
# Out:
# 0        United Kingdom
# 3         United States
# 5                Canada
# 7                 India
# 9                 India
#               ...
# 88859     United States
# 88863    United Kingdom
# 88864             India
# 88877     United States
# 88878            Canada
# Name: Country, Length: 45008, dtype: object

# %%
df["LanguageWorkedWith"].head(10)
# Out:
# 0                                                                       HTML/CSS;Java;JavaScript;Python
# 1                                                                                   C++;HTML/CSS;Python
# 2                                                                                              HTML/CSS
# 3                                                                                   C;C++;C#;Python;SQL
# 4                                                           C++;HTML/CSS;Java;JavaScript;Python;SQL;VBA
# 5                                                                                            Java;R;SQL
# 6                                                                                   HTML/CSS;JavaScript
# 7                                       Bash/Shell/PowerShell;C;C++;HTML/CSS;Java;JavaScript;Python;SQL
# 8    Bash/Shell/PowerShell;C#;HTML/CSS;JavaScript;Python;Ruby;Rust;SQL;TypeScript;WebAssembly;Other(s):
# ...

# %%
python_language_users_filter = (df["LanguageWorkedWith"].str.contains('Python', na=False))

# %%
df.loc[python_language_users_filter, "LanguageWorkedWith"]
# Out:
# 0                                        HTML/CSS;Java;JavaScript;Python
# 1                                                    C++;HTML/CSS;Python
# 3                                                    C;C++;C#;Python;SQL
# 4                            C++;HTML/CSS;Java;JavaScript;Python;SQL;VBA
# 7        Bash/Shell/PowerShell;C;C++;HTML/CSS;Java;JavaScript;Python;SQL
#                                       ...
# 88854    Bash/Shell/PowerShell;C;C++;HTML/CSS;Java;JavaScript;Python;SQL
# 88860                    Bash/Shell/PowerShell;C++;Python;Ruby;Other(s):
# 88865                    Bash/Shell/PowerShell;HTML/CSS;Python;Other(s):
# 88872                           C;C++;HTML/CSS;JavaScript;PHP;Python;SQL
# 88876                                         HTML/CSS;JavaScript;Python
# Name: LanguageWorkedWith, Length: 36443, dtype: object

# %%
python_language_users_filter
# Out:
# 0         True
# 1         True
# 2        False
# 3         True
# 4         True
#          ...
# 88878    False
# 88879    False
# 88880    False
# 88881    False
# 88882    False
# Name: LanguageWorkedWith, Length: 88883, dtype: bool

# %%
df.loc[python_language_users_filter]
# Out:
#        Respondent                              MainBranch Hobbyist  \
# 0               1  I am a student who is learning to code      Yes
# 1               2  I am a student who is learning to code       No
# 3               4          I am a developer by profession       No
# 4               5          I am a developer by profession      Yes
# 7               8             I code primarily as a hobby      Yes
# ...           ...                                     ...      ...
# 88854       84539                                     NaN      Yes
# 88860       85738                                     NaN      Yes
# 88865       86566                                     NaN      Yes
# 88872       87739                                     NaN      Yes
# 88876       88212                                     NaN       No
#
#                                               OpenSourcer  \
# 0                                                   Never
# ...
